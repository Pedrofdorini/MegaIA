# %% [markdown]
# # Fazendo a extração de dados

# %%
import requests
from bs4 import BeautifulSoup
#fazer uma varredura do html dá pagina
response=requests.get("https://www.megasena.com/resultados/ano-2023")
#Verificar se a solicitação foi bem sucedida (status_code 200)
if response.status_code==200:
    #coletar o HTML da página
    html_content=response.text
    soup=BeautifulSoup(html_content,'html.parser')
    numeros_sorteados=soup.find_all('li',class_='ball')
    #verificar se os números sorteados foram encontrados
    if numeros_sorteados:
        #iterar sobre os elementos encontrados e extrair o texto de cada um
        for numero in numeros_sorteados:
            print(numero.text.strip())#imprimir  os números
        print(f"foi encontrado {len(numeros_sorteados)} números")#verificação se tem 720 números o qual verifiquei no site
    else:
        print("não foi possível achar nenhum número")

else:
    print("erro ao acessar a página:",x.status_code)
# Out:
# 21
# 24
# 33
# 41
# 48
# 56
# 4
# 7
# 16
# 35
# 46
# 54
# 1
# 27
# 30
# 41
# 46
# 57
# 1
# 4
# 8
# 21
# 46
# 51
# 5
# 25
# 29
# 30
# 43
# 47
# 3
# 14
# 21
# 22
# 37
# 39
# 12
# 15
# 17
# 30
# 40
# 52
# 7
# 11
# 27
# 41
# 56
# 59
# 17
# 20
# 31
# 34
# 40
# 42
# 6
# 30
# 35
# 38
# 41
# 56
# 6
# 12
# 13
# 20
# 38
# 60
# 11
# 36
# 46
# 53
# 55
# 60
# 5
# 13
# 39
# 51
# 58
# 60
# 7
# 27
# 32
# 33
# 36
# 53
# 20
# 24
# 27
# 46
# 57
# 58
# 10
# 23
# 30
# 31
# 49
# 56
# 11
# 17
# 23
# 36
# 47
# 51
# 14
# 32
# 41
# 43
# 48
# 60
# 13
# 23
# 26
# 29
# 45
# 59
# 6
# 23
# 35
# 36
# 37
# 59
# 9
# 18
# 29
# 37
# 39
# 58
# 6
# 11
# 26
# 32
# 46
# 56
# 20
# 44
# 45
# 46
# 56
# 59
# 9
# 33
# 39
# 43
# 50
# 54
# 18
# 28
# 30
# 39
# 41
# 58
# 8
# 22
# 34
# 42
# 51
# 59
# 4
# 17
# 22
# 28
# 30
# 49
# 2
# 10
# 29
# 31
# 56
# 59
# 8
# 13
# 31
# 33
# 49
# 50
# 9
# 24
# 34
# 39
# 45
# 50
# 4
# 8
# 10
# 27
# 28
# 32
# 2
# 8
# 11
# 22
# 48
# 49
# 9
# 30
# 34
# 44
# 54
# 55
# 1
# 2
# 10
# 32
# 34
# 59
# 5
# 16
# ...
